# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading in .csv file
df = pd.read_csv('creditcard.csv')

# %%
df.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  11959.000000  11959.000000  11959.000000  11959.000000  11959.000000
# mean    8009.996822     -0.216230      0.277097      0.889505      0.282606
# std     6204.332248      1.583914      1.308884      1.331824      1.478162
# min        0.000000    -27.670569    -34.607649    -22.804686     -4.657545
# 25%     2542.000000     -0.978944     -0.261503      0.417186     -0.622456
# 50%     6662.000000     -0.340742      0.256346      0.951223      0.213029
# 75%    12382.000000      1.161273      0.883626      1.613678      1.159141
# max    20642.000000      1.960497      9.092123      4.101716     11.927512
#
#                  V5            V6            V7            V8            V9  \
# count  11959.000000  11959.000000  11959.000000  11959.000000  11959.000000
# mean      -0.086585      0.139986     -0.121943     -0.048727      0.911579
# ...

# %%
#drop the null values
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
sns.countplot(df, x='Class')      #see the number of frauds and genuine
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
#Scaling the data
from sklearn.preprocessing import StandardScaler
scaler  = StandardScaler()
df['Amount_scaled'] = scaler.fit_transform(df['Amount'].values.reshape(-1,1))   #used .reshape() since Amount column was a 1-D array
df['Time_scaled'] = scaler.fit_transform(df['Time'].values.reshape(-1,1))

# %%
df.drop(['Time', 'Amount'], axis=1, inplace=True)

# %%
#perform the split
X = df.drop('Class', axis=1)
y = df['Class']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y ,test_size=0.2, stratify=y, random_state=42)

# %%
#using SMOTE to create synthetic data points
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)

# %%
X_train_resampled, y_train_resampled = smote.fit_resample(X_train,y_train)

# %%
print("Before:", y_train.value_counts())
print("After:", y_train_resampled.value_counts())
# Out:
# Before: Class
# 0.0    9524
# 1.0      42
# Name: count, dtype: int64
# After: Class
# 0.0    9524
# 1.0    9524
# Name: count, dtype: int64

# %%
#Model Training
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
rfc = RandomForestClassifier(class_weight='balanced',random_state=42)

# %%
n_estimators = [64,100,128,256]
max_features = [2,3,4,5]
bootstrap = [True,False]
oob_score = [True,False]

param_grid = {
    'n_estimators': n_estimators,
    'max_features': max_features,
    'bootstrap': bootstrap,
    'oob_score': oob_score
}

# %%
grid = GridSearchCV(rfc,param_grid,cv=5,n_jobs=-1,verbose=1)

# %%
grid.fit(X_train_resampled,y_train_resampled)
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 80 fits failed out of a total of 320.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 80 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
grid.best_params_
# Out:
# {'bootstrap': False, 'max_features': 2, 'n_estimators': 64, 'oob_score': False}

# %%
preds = grid.predict(X_test)
preds_proba = grid.predict_proba(X_test)[:,1]     #selects predicted probabilities that a sample belongs to class 1

# %%
from sklearn.metrics import classification_report, roc_auc_score, f1_score, auc, precision_score, recall_score, precision_recall_curve

# %%
threshold = 0.3     #random value
y_pred_threshold = (preds_proba >= threshold).astype(int)

# %%
print(roc_auc_score(y_test,preds_proba))
# Out:
# 0.94575986565911

# %%
print(f1_score(y_test,y_pred_threshold))
print(recall_score(y_test,y_pred_threshold))
# Out:
# 0.8888888888888888
# 0.8

# %%
#plot precision recall curve
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_threshold)

# %%
#plot the curve
plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
